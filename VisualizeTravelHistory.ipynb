# %%
# !pip install geopatra
# Out:
# Requirement already satisfied: geopandas in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (0.6.3)
# Requirement already satisfied: pandas>=0.23.0 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from geopandas) (1.0.1)
# Requirement already satisfied: shapely in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from geopandas) (1.7.0)
# Requirement already satisfied: pyproj in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from geopandas) (2.6.0)
# Requirement already satisfied: fiona in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from geopandas) (1.8.13.post1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2019.3)
# Requirement already satisfied: attrs>=17 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: cligj>=0.5 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: munch in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: click<8,>=4.0 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: six>=1.7 in /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages (from fiona->geopandas) (1.14.0)

# %%
import pandas as pd
import geopandas

# %%
df = pd.read_json("https://api.steinhq.com/v1/storages/5e737e60b88d3d04ae0815b8/Sheet1")

# %%
df
# Out:
#     Patient              From                To  \
# 0    P38P39     3/4/2020 6:00     3/4/2020 8:00
# 1    P38P39  03/04/2020 19:00  03/04/2020 20:30
# 2    P38P39   03/06/2020 8:15  03/06/2020 10:15
# 3    P38P39  03/06/2020 10:30  03/06/2020 11:15
# 4    P38P39  03/06/2020 14:00  03/06/2020 16:00
# ..      ...               ...               ...
# 235    None              None              None
# 236    None              None              None
# 237    None              None              None
# 238    None              None              None
# 239    None              None              None
#
#                                     Notes/Description  \
# 0    halt at Jathanickal Cherukulangara Bakery, Ranni
# 1                    halt at Marthoma Hospital, Ranni
# 2    travel by Thachilethu Bus from Ranni to Kottayam
# 3    halt at Palathara Textiles, Kanjikuzhy, Kottayam
# 4    travel by Mahiniyam bus from Kanjikuzhy to Ranni
# ..                                                ...
# 235                                              None
# 236                                              None
# 237                                              None
# 238                                              None
# 239                                              None
#
#                                         GoogleMapsLink  \
# 0                                                 None
# 1    https://www.google.com/maps/place/Marthoma+Hos...
# 2                                                 None
# 3    https://www.google.com/maps/place/Palathara+Fa...
# 4                                                 None
# ..                                                 ...
# 235                                               None
# 236                                               None
# 237                                               None
# 238                                               None
# 239                                               None
#
#     Type(placeVisit/Travel) TravelMode  \
# 0                placevisit       None
# 1                placevisit       None
# 2                    Travel        Bus
# 3                placevisit       None
# 4                    Travel        Bus
# ..                      ...        ...
# 235                    None       None
# 236                    None       None
# 237                    None       None
# 238                    None       None
# 239                    None       None
#
#                                       PlaceName        Lat       Long
# 0                                          None        NaN        NaN
# 1                             Marthoma Hospital   9.386575  76.783366
# 2                                          None        NaN        NaN
# 3                            Palathara Fashions   9.596646  76.522531
# 4                                          None        NaN        NaN
# ..                                          ...        ...        ...
# 235                     Areekode, Kerala 673639  11.231327  76.042030
# 236         Government Medical College, Manjeri  11.116293  76.118415
# 237  Kempegowda International Airport Bengaluru  13.198635  77.704404
# 238                                        None        NaN        NaN
# 239                           Kodagu, Karnataka  12.379733  75.219213
#
# [240 rows x 10 columns]

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Long, df.Lat))
gdf.folium.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f8b79515cd87> in <module>
#       1 gdf = geopandas.GeoDataFrame(
#       2     df, geometry=geopandas.points_from_xy(df.Long, df.Lat))
# ----> 3 gdf.folium.plot()
#
# ~/miniconda3/envs/nanda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'folium'

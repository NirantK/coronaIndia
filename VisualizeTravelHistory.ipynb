# %%
# !pip install geopatra

# %%
import pandas as pd
import geopandas
import geopatra

# %%
raw_df = pd.read_json("https://api.steinhq.com/v1/storages/5e737e60b88d3d04ae0815b8/Sheet1")

# %%
df = raw_df[["Patient", "PlaceName", "Lat", "Long"]]

# %%
df.dropna(inplace=True)
# Out:
# /Users/nirant/miniconda3/envs/nanda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     Patient                                       PlaceName        Lat  \
# 1    P38P39                               Marthoma Hospital   9.386575
# 3    P38P39                              Palathara Fashions   9.596646
# 36      P86   Government Medical College Thiruvananthapuram   8.524231
# 37      P86                                Samudra Medicals   8.524343
# 42       R2   hotel Aryaas Koothattukulam Muvattupuzha road   9.861423
# ..      ...                                             ...        ...
# 227    P119                               KNZ Function Hall  17.344732
# 228    P119            ESIC Hospital, Kalaburagi (Gulbarga)  17.321605
# 229    P119                    Cochin International Airport  10.151783
# 231    P175  Haj House, kerala state hajj Committee Karipur  11.150736
# 233    P175                         Areekode, Kerala 673639  11.231327
#
#           Long
# 1    76.783366
# 3    76.522531
# 36   76.925743
# 37   76.927451
# 42   76.581309
# ..         ...
# 227  76.820145
# 228  76.869548
# 229  76.390769
# 231  75.945417
# 233  76.042030
#
# [109 rows x 4 columns]

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Long, df.Lat))
gdf.folium.plot()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

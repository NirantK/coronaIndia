# %%
# !pip install geopatra

# %%
import pandas as pd
import geopandas
import geopatra

# %%
df = pd.read_json("https://api.steinhq.com/v1/storages/5e737e60b88d3d04ae0815b8/Sheet1")

# %%
df
# Out:
#     Patient              From                To  \
# 0    P38P39     3/4/2020 6:00     3/4/2020 8:00
# 1    P38P39  03/04/2020 19:00  03/04/2020 20:30
# 2    P38P39   03/06/2020 8:15  03/06/2020 10:15
# 3    P38P39  03/06/2020 10:30  03/06/2020 11:15
# 4    P38P39  03/06/2020 14:00  03/06/2020 16:00
# ..      ...               ...               ...
# 235    None              None              None
# 236    None              None              None
# 237    None              None              None
# 238    None              None              None
# 239    None              None              None
#
#                                     Notes/Description  \
# 0    halt at Jathanickal Cherukulangara Bakery, Ranni
# 1                    halt at Marthoma Hospital, Ranni
# 2    travel by Thachilethu Bus from Ranni to Kottayam
# 3    halt at Palathara Textiles, Kanjikuzhy, Kottayam
# 4    travel by Mahiniyam bus from Kanjikuzhy to Ranni
# ..                                                ...
# 235                                              None
# 236                                              None
# 237                                              None
# 238                                              None
# 239                                              None
#
#                                         GoogleMapsLink  \
# 0                                                 None
# 1    https://www.google.com/maps/place/Marthoma+Hos...
# 2                                                 None
# 3    https://www.google.com/maps/place/Palathara+Fa...
# 4                                                 None
# ..                                                 ...
# 235                                               None
# 236                                               None
# 237                                               None
# 238                                               None
# 239                                               None
#
#     Type(placeVisit/Travel) TravelMode  \
# 0                placevisit       None
# 1                placevisit       None
# 2                    Travel        Bus
# 3                placevisit       None
# 4                    Travel        Bus
# ..                      ...        ...
# 235                    None       None
# 236                    None       None
# 237                    None       None
# 238                    None       None
# 239                    None       None
#
#                                       PlaceName        Lat       Long
# 0                                          None        NaN        NaN
# 1                             Marthoma Hospital   9.386575  76.783366
# 2                                          None        NaN        NaN
# 3                            Palathara Fashions   9.596646  76.522531
# 4                                          None        NaN        NaN
# ..                                          ...        ...        ...
# 235                     Areekode, Kerala 673639  11.231327  76.042030
# 236         Government Medical College, Manjeri  11.116293  76.118415
# 237  Kempegowda International Airport Bengaluru  13.198635  77.704404
# 238                                        None        NaN        NaN
# 239                           Kodagu, Karnataka  12.379733  75.219213
#
# [240 rows x 10 columns]

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Long, df.Lat))
gdf
gdf.folium.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-daec0c7579aa> in <module>
#       2     df, geometry=geopandas.points_from_xy(df.Long, df.Lat))
#       3 gdf
# ----> 4 gdf.folium.plot()
#
# ~/miniconda3/envs/nanda/lib/python3.7/site-packages/geopatra/map.py in plot(self, **kwargs)
#      19     def plot(self, **kwargs):
#      20         """Plot geodataframe as a geojson."""
# ---> 21         m = folium.geojson(self._gdf, **kwargs)
#      22         return m
#      23
#
# ~/miniconda3/envs/nanda/lib/python3.7/site-packages/geopatra/folium/geojson.py in geojson(gdf, name, width, height, location, color, tooltip, zoom, tiles, attr, style)
#      52
#      53     m = _folium_map(
# ---> 54         gpd_copy, width, height, location, tiles=tiles, attr=attr, zoom_start=zoom
#      55     )
#      56     folium.GeoJson(
#
# ~/miniconda3/envs/nanda/lib/python3.7/site-packages/geopatra/folium/utils.py in _folium_map(gpd_copy, width, height, location, tiles, attr, zoom_start)
#      22     if location is None:
#      23         col = gpd_copy._geometry_column_name
# ---> 24         location = list(reversed(list(gpd_copy.iloc[0][col].centroid.coords[0])))
#      25     m = folium.Map(
#      26         width=width,
#
# IndexError: list index out of range
